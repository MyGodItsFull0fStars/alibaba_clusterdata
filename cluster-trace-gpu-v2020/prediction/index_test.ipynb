# %%
import pandas as pd

# %%
index_df = pd.read_csv('./machine_indices.csv', index_col=0)
index_df.head()
# Out:
#    train_start  train_end  test_start  test_end  length
# 0            0         79          80       113     113
# 1          114        318         319       455     341
# 2          456        486         487       695     239
# 3          696        666         667       952     256
# 4          953       2933        2934      4190    3237

# %%
index_df.iloc[:,[0, 1]]
# Out:
#       train_start  train_end
# 0               0         79
# 1             114        318
# 2             456        486
# 3             696        666
# 4             953       2933
# ...           ...        ...
# 1721      2007112    1405194
# 1722      2007421    1407280
# 1723      2010402    1409405
# 1724      2013437    1409564
# 1725      2013665    1409827
#
# [1726 rows x 2 columns]

# %%
machine_df = pd.read_csv('./df_machine_sorted.csv', index_col=0)
machine_df.head()
# Out:
#                        start_date                  job_name      task_name  \
# 104146  1970-01-28 15:32:43+08:00  9d28a91e7301a697bad12557         worker
# 139760  1970-01-29 16:01:19+08:00  74474bd870f2447ac939f9cd         worker
# 139884  1970-01-29 16:05:16+08:00  a75f2d5a26b8fff5724fdd6d  PyTorchWorker
# 169267  1970-01-30 11:54:59+08:00  0be403d9f0299123cb12c498  PyTorchWorker
# 174797  1970-01-30 14:50:21+08:00  a23b5d2cf2a5c94a8a798ac7  PyTorchWorker
#
#         start_time   end_time                   machine  runtime  plan_cpu  \
# 104146   2359963.0  2360077.0  0018d759f400ef5c0457ab9c    114.0     100.0
# 139760   2448079.0  2448183.0  0018d759f400ef5c0457ab9c    104.0     600.0
# 139884   2448316.0  2448477.0  0018d759f400ef5c0457ab9c    161.0      50.0
# 169267   2519699.0  2530096.0  0018d759f400ef5c0457ab9c  10397.0     300.0
# 174797   2530221.0  2530335.0  0018d759f400ef5c0457ab9c    114.0      50.0
#
# ...

# %%
machine_df.iloc[:, 0: 80]
# Out:
#                         start_date                  job_name      task_name  \
# 104146   1970-01-28 15:32:43+08:00  9d28a91e7301a697bad12557         worker
# 139760   1970-01-29 16:01:19+08:00  74474bd870f2447ac939f9cd         worker
# 139884   1970-01-29 16:05:16+08:00  a75f2d5a26b8fff5724fdd6d  PyTorchWorker
# 169267   1970-01-30 11:54:59+08:00  0be403d9f0299123cb12c498  PyTorchWorker
# 174797   1970-01-30 14:50:21+08:00  a23b5d2cf2a5c94a8a798ac7  PyTorchWorker
# ...                            ...                       ...            ...
# 1898518  1970-03-13 10:17:52+08:00  0a65401bad4458056daa19e1         worker
# 1899829  1970-03-13 10:54:21+08:00  68e69c824ef3739b2026fcda  PyTorchWorker
# 1899942  1970-03-13 10:56:37+08:00  5f3d159308880eb04fec33bb  PyTorchWorker
# 1936024  1970-03-14 12:38:08+08:00  686fbdbc88f3769f073eb527         worker
# 1952195  1970-03-15 01:09:06+08:00  f8ce59e595168642575b09a3         worker
#
# ...

# %%
test = machine_df.iloc[:, ]

# %%
train_start_index = index_df['train_start'].values
train_end_index = index_df['train_end'].values

for idx in range(len(index_df)):
    machine_df.iloc[:, train_start_index[idx]:train_end_index[idx]]
