# %% [markdown]
# # Training Set Preparation
#
# In this notbook, the (already pre-processed) dataset `preprocessed_worker.csv` will further be transformed to be usuable for the training with the notebook `lstm_utilization_prediction.ipynb`.

# %% [markdown]
# ## Import Modules

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## Load the Dataset

# %%
DF_PATH: str = 'preprocessed_worker.csv'

df = pd.read_csv(DF_PATH, index_col='start_date', parse_dates=True)
df.head(15)
# Out:
#                            Unnamed: 0                  job_name  \
# start_date
# 1970-02-03 22:21:22+08:00           0  90aa0b961ab6bd02e95614d4
# 1970-02-06 09:45:06+08:00           1  8194a80f52649c125707ba67
# 1970-02-08 11:45:59+08:00           2  585adc8d135ec0d9949d3ed0
# 1970-02-11 05:45:54+08:00           3  5f020c58e4db9328d3f45d98
# 1970-02-11 05:46:20+08:00           4  cff6e4809f8b13651d8e78d5
# 1970-02-23 17:48:10+08:00           5  c5d490180630ff58bbb96d67
# 1970-02-24 01:26:51+08:00           6  91b992713adfd80280308bd2
# 1970-02-26 18:10:20+08:00           7  d3815e6d7a10c0b0b7209175
# 1970-02-27 16:39:44+08:00           8  1b04d52520f32cafc5847651
# 1970-02-28 05:19:39+08:00           9  50a56e3b7f0450089a6c2622
# 1970-03-02 18:47:51+08:00          10  1ada71da86320573520f6f28
# 1970-01-29 16:01:19+08:00          11  74474bd870f2447ac939f9cd
# 1970-02-03 11:49:00+08:00          12  2149bdf612dadd70b0b62ac6
# 1970-02-05 15:01:33+08:00          13  05abcd31838f68f856108b3a
# 1970-02-06 11:16:33+08:00          14  72a5250a54a0942943a143dd
#
#                                task_name  \
# start_date
# 1970-02-03 22:21:22+08:00         worker
# 1970-02-06 09:45:06+08:00  PyTorchWorker
# 1970-02-08 11:45:59+08:00  PyTorchWorker
# 1970-02-11 05:45:54+08:00         worker
# 1970-02-11 05:46:20+08:00         worker
# 1970-02-23 17:48:10+08:00         worker
# 1970-02-24 01:26:51+08:00         worker
# 1970-02-26 18:10:20+08:00  PyTorchWorker
# 1970-02-27 16:39:44+08:00  PyTorchWorker
# 1970-02-28 05:19:39+08:00         worker
# 1970-03-02 18:47:51+08:00  PyTorchWorker
# 1970-01-29 16:01:19+08:00         worker
# 1970-02-03 11:49:00+08:00  PyTorchWorker
# 1970-02-05 15:01:33+08:00  PyTorchWorker
# 1970-02-06 11:16:33+08:00  PyTorchWorker
#
#                                                                    inst_name  \
# start_date
# 1970-02-03 22:21:22+08:00  86e4930e3519672d74e244e3729201e4aeaef427a66f67...
# 1970-02-06 09:45:06+08:00  3d81df38ac177236979223b593ec13ef6289670caf637e...
# 1970-02-08 11:45:59+08:00  377e43b5ec60a0d0ad6bf6b2e12ef1e5dc3f9424c7dcf4...
# 1970-02-11 05:45:54+08:00  6e344ab96bc1e709bce9bbbcc97f549e358ae43e69e87a...
# 1970-02-11 05:46:20+08:00  02a456c6f479375362f42e5e5aec04589c1d951b299e5c...
# 1970-02-23 17:48:10+08:00  c5499b320ba72babbdebe70d0241d41a7a0d7d592bafe8...
# 1970-01-29 16:01:19+08:00   1.835938        0.441632        0.993164
# 1970-02-03 11:49:00+08:00  40.742188        6.672949        6.723633
# 1970-02-05 15:01:33+08:00  40.434570        6.690867        6.778320
# 1970-02-06 11:16:33+08:00  39.921875        6.705428        6.778320
#
# [15 rows x 32 columns]

# %% [markdown]
# ## Sort the Dataset
#
# The dataset gets sorted first by each `machine` and then each machine gets sorted by its `start_date` index.
#
# So the data is ascending for each machine.

# %%
df = df.sort_values(['start_date'])

# %%
df['job_name'].value_counts()
# Out:
# f8ce59e595168642575b09a3    528
# 94b340f2cdedf37303d41bf2    365
# f36b806178de547bc6c5d18f    316
# d4edeca9d055992562873954    302
# 72aeefbaed67e4f7f5370474    288
#                            ...
# 0d8291183950520908a323d9      1
# 20d0bbce025e47dae66eb139      1
# ee5995674f9393f9e90363f4      1
# 4edd2b9f66a96f243f7dc807      1
# 597e5ca27dc3872247351d2d      1
# Name: job_name, Length: 580972, dtype: int64

# %% [markdown]
# # Drop not needed Columns

# %%
df.drop(columns=['Unnamed: 0', 'inst_name', 'inst_id', 'worker_name', 'gpu_name', 'start_time_t', 'end_time_t'], inplace=True)
term_val = 'Terminated'
df.query('status_t == @term_val', inplace=True)
# df.dropna(axis=0, inplace=True)

# %%
df.columns
# Out:
# Index(['job_name', 'task_name', 'start_time', 'end_time', 'machine', 'runtime',
#        'inst_num', 'status_t', 'plan_cpu', 'plan_mem', 'plan_gpu', 'gpu_type',
#        'user', 'gpu_type_spec', 'group', 'workload', 'cap_cpu', 'cap_mem',
#        'cap_gpu', 'cpu_usage', 'gpu_wrk_util', 'avg_mem', 'max_mem',
#        'avg_gpu_wrk_mem', 'max_gpu_wrk_mem'],
#       dtype='object')

# %% [markdown]
# ## Create Dataframe with Columns used for Machine Learning
#
# Next we will create the dataframe that holds all values we will use for machine learning.

# %%
training_columns: list = ['machine', 'task_name', 'inst_num', 'cpu_usage',
                          'gpu_wrk_util', 'avg_mem', 'max_mem', 'avg_gpu_wrk_mem',
                          'max_gpu_wrk_mem', 'cap_cpu', 'cap_mem',
                          'cap_gpu', 'runtime']

machine_df = df[training_columns]

# %% [markdown]
# ## Save Dataframe to Disk
#
# In order to later on use the dataframe, we will store it to disk.

# %%
# machine_df = pd.read_csv('training_machine_sorted_df.csv', index_col='start_date')

# %%
machine_df

# %%
machine_df.shape
# Out:
# (1954769, 13)

# %%
dummies = pd.get_dummies(machine_df['task_name'])
dummies.shape

# %%
machine_df = pd.concat([machine_df, dummies], axis=1)
machine_df.shape

# %%
machine_df.columns

# %%
machine_df.drop(columns=['machine', 'task_name'], inplace=True)
machine_df.dropna(axis=0, inplace=True)

# %%
machine_df.shape

# %%
from math import ceil


split_ratio = 0.7
split_index = ceil(len(machine_df) * split_ratio)

training_df = machine_df.iloc[0:split_index]
test_df = machine_df.iloc[split_index:]

# %%
training_df.to_csv('training_df.csv')
test_df.to_csv('test_df.csv')
