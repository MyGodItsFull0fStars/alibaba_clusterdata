# %%
import torch
import pandas as pd
import numpy as np

from utils import get_df

# %%
DATA_DIR: str = '../data'

df = pd.read_csv('../data/df_worker_sensor.csv')
# Out:
# /var/folders/dj/hxzphr3j0617vybm1xdwl_tw0000gn/T/ipykernel_37970/824233925.py:3: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../data/df_worker_sensor.csv')

# %%
df.shape
# Out:
# (3019349, 38)

# %%
df.head(15)
# Out:
#     Unnamed: 0                  job_name   task_name  \
# 0            0  337bc6f19baecbc9706b6492      worker
# 1            1  e4df78c45628acfc1b532387  tensorflow
# 2            2  db21abf3954bd9418ba54df5      worker
# 3            3  272c73f1eb7daf9f7cd88d91      worker
# 4            4  93f4887f4e4e8c478bc679c5      worker
# 5            5  e5d6d5b546bff61f93b47ebf      worker
# 6            6  108310c4b751b1855e8acc47      worker
# 7            7  2074763b6ab0969181e341f1      worker
# 8            8  a7daa3931b9188dfe7a3040d      worker
# 9            9  6b147d05f96bef1bfc4e5c84      worker
# 10          10  cdddf5b038c00eb929940ed1  tensorflow
# 11          11  70a0ecaf1bb0a632b9a95a9b      worker
# 12          12  2fed9aab202dd29c76993b2d      worker
# 13          13  411d1552a0704b26edca5d1d      worker
# 14          14  70a0ecaf1bb0a632b9a95a9b      worker
#
#                                             inst_name  \
# 0   41e7eb6c7170b2cb514be986397729655b97dd80fd2106...
# ...

# %%
df.drop(columns=['Unnamed: 0', 'read', 'write', 'read_count', 'write_count', 'task_name'], inplace=True)

# %% [markdown]
# Only keep tasks that terminated successfully.

# %%
df.query("status == 'Terminated'", inplace=True)
df.drop(columns=['status'], inplace=True)
df.head(15)
# Out:
#                          job_name      task_name  \
# 1005309  9065b8d2465a8b4b8073e70f  PyTorchWorker
# 1005310  ab81a8ed003c5af878460000         worker
# 1005311  ab81a8ed003c5af878460000         worker
# 1005312  ab81a8ed003c5af878460000         worker
# 1005313  ab81a8ed003c5af878460000         worker
# 1005314  ab81a8ed003c5af878460000         worker
# 1005315  ab81a8ed003c5af878460000         worker
# 1005316  ab81a8ed003c5af878460000         worker
# 1005317  ab81a8ed003c5af878460000         worker
# 1005318  ab81a8ed003c5af878460000         worker
# 1005319  ab81a8ed003c5af878460000         worker
# 1005320  ab81a8ed003c5af878460000         worker
# 1005321  ab81a8ed003c5af878460000         worker
# 1005322  ab81a8ed003c5af878460000         worker
# 1005323  ab81a8ed003c5af878460000         worker
#
#                                                  inst_name  \
# 1005309  d04df70cfcd7457e262c4fcadb6c1845ad9aa89c337da6...
# ...

# %%
df.sort_values(['machine', 'gpu_name', 'start_time'], inplace=True)
df.head(15)
# Out:
#                          job_name      task_name  \
# 1326731  90aa0b961ab6bd02e95614d4         worker
# 1414891  8194a80f52649c125707ba67  PyTorchWorker
# 1490455  585adc8d135ec0d9949d3ed0  PyTorchWorker
# 1608579  5f020c58e4db9328d3f45d98         worker
# 1608653  cff6e4809f8b13651d8e78d5         worker
# 2093308  c5d490180630ff58bbb96d67         worker
# 2106977  91b992713adfd80280308bd2         worker
# 2237467  d3815e6d7a10c0b0b7209175  PyTorchWorker
# 2281694  1b04d52520f32cafc5847651  PyTorchWorker
# 2301039  50a56e3b7f0450089a6c2622         worker
# 2404215  1ada71da86320573520f6f28  PyTorchWorker
# 1145069  74474bd870f2447ac939f9cd         worker
# 1309114  2149bdf612dadd70b0b62ac6  PyTorchWorker
# 1386648  05abcd31838f68f856108b3a  PyTorchWorker
# 1419622  72a5250a54a0942943a143dd  PyTorchWorker
#
#                                                  inst_name  \
# 1326731  86e4930e3519672d74e244e3729201e4aeaef427a66f67...
# ...

# %%
df.shape
# Out:
# (2014040, 33)

# %%
df.to_csv('preprocessed_worker.csv')
