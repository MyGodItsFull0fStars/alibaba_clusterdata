# %%
import torch
import pandas as pd
import numpy as np

from utils import get_df

# %%
torch.cuda.is_available()
# Out:
# False

# %%
DATA_DIR: str = '../data'

sensor_df = get_df(f'{DATA_DIR}/pai_sensor_table.csv')
sensor_df.drop(columns=['job_name', 'task_name', 'read', 'write', 'read_count', 'write_count'], inplace=True)

sensor_df.head()
# Out:
#                                          worker_name  \
# 0  d50591d4a39b5a68e7efa15a0b51cfdca03e8f7a49ade7...
# 1  fd1ee8bacf027604c2afdf89fc4edd843322b78376c9df...
# 2  8885c53fd558926cb6aa44bbb7f40e242093778988c57d...
# 3  8170c081a8d69cc228b9c2fa13a1c5e1190bf215296816...
# 4  e43f95191455f15365b40289c32b44648ce1e501331119...
#
#                                              inst_id  \
# 0  dc6e6daefec62bc3729def7e15133c03b82a97a1457d68...
# 1  dc6e6daefec62bc3729def7e15133c03b82a97a1457d68...
# 2  dc6e6daefec62bc3729def7e15133c03b82a97a1457d68...
# 3  ccc2b2c5742997e7ed0459efa6ec3db8b8e56e3f7fcd5f...
# 4  ccc2b2c5742997e7ed0459efa6ec3db8b8e56e3f7fcd5f...
#
#                     machine      gpu_name   cpu_usage  gpu_wrk_util   avg_mem  \
# 0  4a57d4f3d41316da3c4ae876  /dev/nvidia5    0.603296      0.000000  0.232509
# 1  d84f5bc585e4ac5d24b30ec1  /dev/nvidia7    1.039332      0.000000  0.305684
# 2  b8dca09e0247ec64355414f9  /dev/nvidia2    0.287556      0.000000  0.345654
# ...

# %%
# sensor_df.sort_values('machine')
# Out:
#                                                worker_name  \
# 1438285  3d89b0a32771c7381dc82290335fa4a0984a1c474d74e6...
# 1776018  58290e2c040b949981ce82f3567ddd4c9c400db57ef4cd...
# 1776088  50729cc799287b5d6833a639e92d65012dee7d48f2c863...
# 1776100  57b278ff349d1c0d0f826cd3cbba156a07411a344ad956...
# 1431917  ed13ffeb9de5bec7d13dcb3103de3a0cab85d4bc7c20e1...
# ...                                                    ...
# 2499697  6d9f084d310d3cdc5b355db362aa22337431caf768b202...
# 654402   f3d57773c55bd0bda11a77ff247c8eecc59e28fd727a33...
# 3008665  6be367eb8fbab9f78349827197f331de00173224ef8ade...
# 297731   eef6fe8c0be010a3bac636024f55b3996d3fe802bafe18...
# 2373358  99180595bd1b8faba4e60742ee7c51d1a74a8e380a609a...
#
#                                                    inst_id  \
# 1438285  bdfe140c3525085fcf2a21027ec2404f83dee6933742c2...
# 1776018  0f9067b978527aed12404e7964559d1ef845523cfbfc1b...
# 1776088  f23ed8a71c4132fe4c246a3d7ffdae98a71fcb16c81390...
# ...

# %%
instance_table_df = get_df(f'{DATA_DIR}/pai_instance_table.csv')
instance_table_df.drop(columns=['task_name', 'status'], inplace=True)
instance_table_df.head()
# Out:
#                    job_name  \
# 0  54670e2998350a9f0e4868d5
# 1  54670e2998350a9f0e4868d5
# 2  54670e2998350a9f0e4868d5
# 3  54670e2998350a9f0e4868d5
# 4  54670e2998350a9f0e4868d5
#
#                                            inst_name  \
# 0  c47ee192deea8c5aa87d8d7c2e02120cd03f75304a69dd...
# 1  92759a73039692b2d3e0929cadf55f5b07b40d6582c36f...
# 2  b3e42abde4c35da06ff4746802b82678b1bf56b28efaa1...
# 3  d0f2e1f76ff463bcd08302370cc2f9bf0ec1333a3b25e3...
# 4  0243b1305fd38f228634b23f69de5ed5ce801360eeffdc...
#
#                                          worker_name  \
# 0  05b1590648df3f4c6deea2496bbbefd4d3ae93347669f7...
# 1  cbc1bc591c53301bceafa44dc626288fd92d2fc5dca438...
# 2  09d41bf627188adc004b2db7c0a47578325952cc3340af...
# 3  1a631e8be3fd787c2891c15b9e9bac6df4f177efc9ec7b...
# 4  59aea81c00cccb5cd01ca2f7f72877d6bc73b427821986...
#
#                                              inst_id  start_time   end_time  \
# ...

# %%
# too big
# merged_df = sensor_df.merge(instance_table_df, left_on='machine', right_on='machine')

# %% [markdown]
# ## Count all Occurrences of a Machine

# %%
machine_count = sensor_df.groupby('machine').count()
machine_count.drop(machine_count.columns[1:], axis=1, inplace=True)
machine_count.rename(columns={'worker_name': 'count'}, inplace=True)
machine_count
# Out:
#                           count
# machine
# 0018d759f400ef5c0457ab9c    265
# 003357a5d5282ec3972d13c0    514
# 004405a7896b1e55546dd4b2    380
# 0054b042d12d996eb494f4f0    463
# 0079479df570af6e43cb37c6   4908
# ...                         ...
# ff82d9bc396cda91ba7b4ce3    561
# ffa083856bd1d23e8701a43f   4632
# ffb1bc4dc2fbb09d0477f0f0   4844
# ffe77b7e12a80177cd4a403b    279
# ffe93e263a503bff83bca28d    656
#
# [1737 rows x 1 columns]

# %%
machine_small = machine_count.query('count == 265')
machine_small
# Out:
#                           count
# machine
# 0018d759f400ef5c0457ab9c    265

# %%
machine_small = machine_small.merge(instance_table_df, left_on='machine', right_on='machine')
machine_small = machine_small.dropna(axis=0)
machine_small
# Out:
#                       machine  count                  job_name  \
# 3    0018d759f400ef5c0457ab9c    265  50d26c42a889896eecab5b38
# 4    0018d759f400ef5c0457ab9c    265  0c9b9335440c7b1e8e162fd5
# 6    0018d759f400ef5c0457ab9c    265  5b153b3ed45e013442ee7e89
# 9    0018d759f400ef5c0457ab9c    265  ea19c300c421be661e57d091
# 10   0018d759f400ef5c0457ab9c    265  eaaf893f4b1fee05f053bb87
# ..                        ...    ...                       ...
# 649  0018d759f400ef5c0457ab9c    265  e170a7b32fd470b0296730a6
# 650  0018d759f400ef5c0457ab9c    265  e170a7b32fd470b0296730a6
# 652  0018d759f400ef5c0457ab9c    265  6f930fea16d78c0a651e6046
# 653  0018d759f400ef5c0457ab9c    265  e121d0be76f3071ef98e24a5
# 656  0018d759f400ef5c0457ab9c    265  29c057fb7fa69cf56c37d9c5
#
#                                              inst_name  \
# 3    5da2cdff5eb7cbe777de57698d4f513fec13e740c53aa3...
# 4    b2792a6329b7f3f2e0ff542f05637ed5819052c8cc139a...
# ...

# %%
machine_small = machine_small.merge(sensor_df, left_on='inst_id', right_on='inst_id')
machine_small
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/macbook/Development/alibaba_clusterdata/cluster-trace-gpu-v2020/prediction/lstm_utilization_prediction.ipynb Cell 11 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/macbook/Development/alibaba_clusterdata/cluster-trace-gpu-v2020/prediction/lstm_utilization_prediction.ipynb#ch0000012?line=0'>1</a> machine_small = machine_small.merge(sensor_df, left_on='inst_name', right_on='inst_name')
#       <a href='vscode-notebook-cell:/Users/macbook/Development/alibaba_clusterdata/cluster-trace-gpu-v2020/prediction/lstm_utilization_prediction.ipynb#ch0000012?line=1'>2</a> machine_small
#
# File ~/opt/miniconda3/envs/ml_pytorch/lib/python3.9/site-packages/pandas/core/frame.py:9351, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
# ...

# %%
machine_small.sort_values('start_time')
# Out:
#                         machine  count                  job_name  \
# 5496   0018d759f400ef5c0457ab9c    265  388052dece9f6c1adc0f20a5
# 5466   0018d759f400ef5c0457ab9c    265  388052dece9f6c1adc0f20a5
# 5467   0018d759f400ef5c0457ab9c    265  388052dece9f6c1adc0f20a5
# 5468   0018d759f400ef5c0457ab9c    265  388052dece9f6c1adc0f20a5
# 5469   0018d759f400ef5c0457ab9c    265  388052dece9f6c1adc0f20a5
# ...                         ...    ...                       ...
# 73499  0018d759f400ef5c0457ab9c    265  600cc43b2df05d9c42fba36c
# 73500  0018d759f400ef5c0457ab9c    265  600cc43b2df05d9c42fba36c
# 73501  0018d759f400ef5c0457ab9c    265  600cc43b2df05d9c42fba36c
# 73487  0018d759f400ef5c0457ab9c    265  600cc43b2df05d9c42fba36c
# 73668  0018d759f400ef5c0457ab9c    265  600cc43b2df05d9c42fba36c
#
#                                                inst_name  \
# 5496   99b01039bf9487c78e8f57b01ee23d16ac9f85eb416b10...
# 5466   99b01039bf9487c78e8f57b01ee23d16ac9f85eb416b10...
# ...
