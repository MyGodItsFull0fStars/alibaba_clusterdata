# %%
# -----------------------------------------------------------
# IMPORT ALL NECESSARY MODULES
# -----------------------------------------------------------

from sklearn.metrics import mean_squared_error, mean_absolute_error
import math
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv('training_df_small.csv')
df['timestamp'] = pd.to_datetime(df['start_date'])
df = df.set_index('timestamp')
df = df.sort_index()
df.drop(columns=['start_date'], inplace=True)
df.head()
# Out:
#                        cpu_usage  gpu_wrk_util   avg_mem    max_mem  \
# timestamp
# 1970-01-28 15:32:43    35.636364      0.080000  2.060832  32.796875
# 1970-01-29 16:01:19    51.043478     13.692308  0.780721   1.835938
# 1970-01-29 16:05:16    59.483871     24.029412  3.403646  37.934570
# 1970-01-30 11:54:59  8021.102453     77.019231  4.084847  37.093750
# 1970-01-30 14:50:21    81.285714     42.958333  4.360521  37.631836
#
#                      avg_gpu_wrk_mem  max_gpu_wrk_mem  runtime
# timestamp
# 1970-01-28 15:32:43         2.447969         4.208984    114.0
# 1970-01-29 16:01:19         0.441632         0.993164    104.0
# 1970-01-29 16:05:16         2.487621         6.723633    161.0
# 1970-01-30 11:54:59         6.160750         6.541992  10397.0
# 1970-01-30 14:50:21         3.374715         6.723633    114.0

# %%
df.plot(figsize=(16, 8))
plt.show()

# %%
# -----------------------------------------------------------
# CREATE TRAIN-TEST SPLIT (80:20)
# -----------------------------------------------------------
TRAIN_LENGTH = round(len(df) * 0.8)
TEST_LENGTH = len(df) - TRAIN_LENGTH
train = df.iloc[0:TRAIN_LENGTH]
test = df[TRAIN_LENGTH:]

# %%
train
# Out:
#                        cpu_usage  gpu_wrk_util   avg_mem    max_mem  \
# timestamp
# 1970-01-28 15:32:43    35.636364      0.080000  2.060832  32.796875
# 1970-01-29 16:01:19    51.043478     13.692308  0.780721   1.835938
# 1970-01-29 16:05:16    59.483871     24.029412  3.403646  37.934570
# 1970-01-30 11:54:59  8021.102453     77.019231  4.084847  37.093750
# 1970-01-30 14:50:21    81.285714     42.958333  4.360521  37.631836
# ...                          ...           ...       ...        ...
# 1970-02-27 15:47:57   124.901235    107.771084  6.019778  36.113281
# 1970-02-27 16:39:44    66.450000     98.695652  3.183949  36.982422
# 1970-02-27 16:41:29   125.064935    114.544304  6.457649  38.242188
# 1970-02-28 05:19:39    60.608696     15.130435  1.159519   7.933594
# 1970-02-28 09:12:52   119.782904    128.695946  7.920469  41.040039
#
#                      avg_gpu_wrk_mem  max_gpu_wrk_mem  runtime
# timestamp
# 1970-01-28 15:32:43         2.447969         4.208984    114.0
# 1970-01-29 16:01:19         0.441632         0.993164    104.0
# 1970-01-29 16:05:16         2.487621         6.723633    161.0
# 1970-01-30 11:54:59         6.160750         6.541992  10397.0
# 1970-01-30 14:50:21         3.374715         6.723633    114.0
# ...                              ...              ...      ...
# 1970-02-27 15:47:57         5.840985         6.817383    401.0
# 1970-02-27 16:39:44         2.651070         6.729492    103.0
# 1970-02-27 16:41:29         5.697575         6.817383    382.0
# 1970-02-28 05:19:39         1.143300         2.266602     99.0
# 1970-02-28 09:12:52         7.313961         7.438477   3689.0
#
# [91 rows x 7 columns]

# %%
# -----------------------------------------------------------
# SCALING VALUES
# -----------------------------------------------------------

# https://cnvrg.io/pytorch-lstm/

mm_scaler = MinMaxScaler()
ss_scaler = StandardScaler()
X_ss = pd.DataFrame(ss_scaler.fit_transform(train))
y_mm = pd.DataFrame(mm_scaler.fit_transform(test))

# %% [markdown]
# ## Split the Dataset
#
# Now the dataset gets split into test and training dataset.
#
# *Note: To later be able to convert the dataset into Tensors, it is necessary to convert them to numpy arrays via `.to_numpy()`*.

# %%
TRAIN_SPLIT: int = 14
TEST_SPLIT = TRAIN_SPLIT + 9

X_train = X_ss[:TRAIN_SPLIT].to_numpy()
X_test = X_ss[TRAIN_SPLIT:TEST_SPLIT].to_numpy()

y_train = y_mm[:TRAIN_SPLIT].to_numpy()
y_test = y_mm[TRAIN_SPLIT:].to_numpy()

print("Training Shape", X_train.shape, y_train.shape)
print("Testing Shape", X_test.shape, y_test.shape)
# Out:
# Training Shape (14, 7) (14, 7)
# Testing Shape (9, 7) (9, 7)

# %%
import torch
import torch.nn as nn
from torch.autograd import Variable

# %%
X_train_tensors = Variable(torch.Tensor(X_train))
X_test_tensors = Variable(torch.Tensor(X_test))

y_train_tensors = Variable(torch.Tensor(y_train))
y_test_tensors = Variable(torch.Tensor(y_test))

# %% [markdown]
# ## Reshaping to Rows, Timestamps and Features

# %%
X_train_tensors_final = torch.reshape(X_train_tensors, (X_train_tensors.shape[0], 1, X_train_tensors.shape[1]))
X_test_tensors_final = torch.reshape(X_test_tensors, (X_test_tensors.shape[0], 1, X_test_tensors.shape[1]))

print("Training Shape", X_train_tensors_final.shape, y_train_tensors.shape)
print("Testing Shape", X_test_tensors_final.shape, y_test_tensors.shape)
# Out:
# Training Shape torch.Size([14, 1, 7]) torch.Size([14, 7])
# Testing Shape torch.Size([9, 1, 7]) torch.Size([9, 7])

# %% [markdown]
# ## Create the LSTM Model

# %%
class LSTM(nn.Module):

    def __init__(self, num_classes: int, input_size: int, hidden_size: int, num_layers: int, seq_length: int) -> None:
        super(LSTM, self).__init__()
        self.num_classes: int = num_classes
        self.input_size: int = input_size
        self.hidden_size: int = hidden_size
        self.num_layers: int = num_layers
        self.seq_length: int = seq_length

        # long-short term memory layer
        self.lstm = nn.LSTM(
            input_size=input_size,
            hidden_size=hidden_size,
            num_layers=num_layers,
            batch_first=True)

        # first fully connected layer
        self.fc_1 = nn.Linear(hidden_size, 128)
        # second fully connected layer
        self.fc_2 = nn.Linear(128, num_classes)
        # activation function
        self.relu = nn.ReLU()

    def forward(self, input):
        hidden_state = Variable(torch.zeros(self.num_layers, input.size(0), self.hidden_size))
        internal_state = Variable(torch.zeros(self.num_layers, input.size(0), self.hidden_size))

        # Propagate input through LSTM
        output, (hn, cn) = self.lstm(input, (hidden_state, internal_state))
        # Reshaping the data for the Dense layer
        hn = hn.view(-1, self.hidden_size)
        out = self.relu(hn)
        out = self.fc_1(out)
        out = self.relu(out)
        out = self.fc_2(out)
        
        return out

# %%
num_epochs: int = 2000
learning_rate: float = 0.001

# number of features
input_size: int = 7
# number of features in hidden state
hidden_size: int = 2
# number of stacked lstm layers
num_layers: int = 1
# number of output classes
num_classes: int = 7

# %% [markdown]
# ## Instantiate the LSTM object

# %%
lstm = LSTM(num_classes, input_size, hidden_size, num_layers, X_train_tensors_final.shape[1])

# %% [markdown]
# ## Define the Loss Function and Optimizer

# %%
from pickletools import optimize

# mean squared error for regression
criterion = nn.MSELoss()
# optimizer function
optimizer = torch.optim.AdamW(lstm.parameters(), lr=learning_rate)

# %%
for epoch in range(num_epochs):
    # forward pass
    outputs = lstm.forward(X_train_tensors_final)
    # calculates the gradient and manually setting to 0
    optimizer.zero_grad()

    # obtain the loss function
    loss = criterion(outputs, y_train_tensors)

    # calculates the loss of the loss function
    loss.backward()

    optimizer.step()  # improve from loss, i.e backprop
    if epoch % 100 == 0:
        print("Epoch: %d, loss: %1.5f" % (epoch, loss.item()))
# Out:
# Epoch: 0, loss: 0.15608
# Epoch: 100, loss: 0.06708
# Epoch: 200, loss: 0.05574
# Epoch: 300, loss: 0.04801
# Epoch: 400, loss: 0.04332
# Epoch: 500, loss: 0.03925
# Epoch: 600, loss: 0.03421
# Epoch: 700, loss: 0.02767
# Epoch: 800, loss: 0.02105
# Epoch: 900, loss: 0.01580
# Epoch: 1000, loss: 0.01255
# Epoch: 1100, loss: 0.01048
# Epoch: 1200, loss: 0.00888
# Epoch: 1300, loss: 0.00746
# Epoch: 1400, loss: 0.00619
# Epoch: 1500, loss: 0.00502
# Epoch: 1600, loss: 0.00398
# Epoch: 1700, loss: 0.00313
# Epoch: 1800, loss: 0.00250
# Epoch: 1900, loss: 0.00206

# %%
# old transformers
df_X_ss = ss_scaler.transform(df)
df_y_mm = mm_scaler.transform(df)

# converting to Tensors
df_X_ss = Variable(torch.Tensor(df_X_ss))
df_y_mm = Variable(torch.Tensor(df_y_mm))
# reshaping the dataset
df_X_ss = torch.reshape(df_X_ss, (df_X_ss.shape[0], 1, df_X_ss.shape[1]))

# %%
# Evaluation Mode
lstm.eval()

# forward pass
train_predict = lstm(df_X_ss)
data_predict = train_predict.data.numpy()
dataY_plot = df_y_mm.data.numpy()

data_predict = mm_scaler.inverse_transform(
    data_predict)  # reverse transformation
dataY_plot = mm_scaler.inverse_transform(dataY_plot)
plt.figure(figsize=(10, 6))  # plotting
plt.axvline(x=TRAIN_SPLIT, c='r', linestyle='--')  # size of the training set

plt.plot(dataY_plot, label=df.columns)  # actual plot
pred_colums = ['pred_' + col for col in df.columns]
plt.plot(data_predict, label=pred_colums)  # predicted plot
plt.title('Time-Series Prediction')
plt.legend()
plt.show()

# %% [markdown]
# ### Root Mean Squared Error (RMSE)
#
# $\operatorname{RMSD}(\hat{\theta}) = \sqrt{\operatorname{MSE}(\hat{\theta})} = \sqrt{\operatorname{E}((\hat{\theta}-\theta)^2)}$

# %%
rmse_result = math.sqrt(mean_squared_error(y_test[:], preds[:]))
print(f'Test Score: {rmse_result:.2f} RMSE')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/macbook/Development/alibaba_clusterdata/cluster-trace-gpu-v2020/prediction/lstm-cpu-usage.ipynb Cell 22 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/macbook/Development/alibaba_clusterdata/cluster-trace-gpu-v2020/prediction/lstm-cpu-usage.ipynb#ch0000031?line=0'>1</a> rmse_result = math.sqrt(mean_squared_error(y_test[:], preds[:]))
#       <a href='vscode-notebook-cell:/Users/macbook/Development/alibaba_clusterdata/cluster-trace-gpu-v2020/prediction/lstm-cpu-usage.ipynb#ch0000031?line=1'>2</a> print(f'Test Score: {rmse_result:.2f} RMSE')
#
# NameError: name 'preds' is not defined

# %% [markdown]
# ### Mean Absolute Error (MAE)
#
# $\mathrm {MAE} ={\frac {\sum _{i=1}^{n}\left|y_{i}-x_{i}\right|}{n}}={\frac {\sum _{i=1}^{n}\left|e_{i}\right|}{n}}
# $

# %%
mae_result = mean_absolute_error(y_test[:], preds[:])
print(f'Test Score: {mae_result} MAE')

# %% [markdown]
# ### Mean Absolute Percentage Error (MAPE)
#
# $MAPE={\frac {100\%}{n}}\sum _{t=1}^{n}\left|{\frac {A_{t}-F_{t}}{A_{t}}}\right|$
#
# The **mean absolute percentage error (MAPE)**, is a measure of prediction accuracy of a forecasting (prediction) method in statistics.
#
# $A_t$ is the actual value and $F_t$ is the predicted value. Their difference is divided by the actual value $A_t$.
#
# The absolute value in this ration is summed for every predicted point in time and divided by the number of fitted points $n$.

# %%
mape_result = np.mean(np.abs(y_test - preds)/np.abs(y_test)*100)
print(f'Test Score: {mape_result} MAPE')
